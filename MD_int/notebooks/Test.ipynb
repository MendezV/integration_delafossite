# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
np.load("/Users/jfmv/Documents/Proyectos/Delafossites/integration_delafossite/MD_int/Res_opt/ActualJ/Half_F/dsf2_1000/T_1.0_fit.npy")
# Out:
# array([-0.03920061, -0.05488086, -0.07317448, ...,  0.00784012,
#        -0.0104535 , -0.02874712])

# %%
T=1.0
with open("/Users/jfmv/Documents/Proyectos/Delafossites/integration_delafossite/MD_int/Res_opt/ActualJ/Half_F/dsf2_1000/T_"+str(T)+'_fit.npy', 'rb') as f:

    xFS_dense = np.load(f)
    yFS_dense = np.load(f)
    angles = np.load(f)
    shifts = np.load(f)
plot(angles, shifts, '.')

# %%
for T in [1.0,2.0,3.0,10.0,50.0]:
    with open("/Users/jfmv/Documents/Proyectos/Delafossites/integration_delafossite/MD_int/Res_opt/ActualJ/Half_F/dsf2_1000/T_"+str(T)+'_fit.npy', 'rb') as f:

        xFS_dense = np.load(f)
        yFS_dense = np.load(f)
        angles = np.load(f)
        shifts = np.load(f)
    scatter(angles, shifts, s=3)

# %%
for T in [1.0,2.0,3.0,10.0,50.0]:
    with open("/Users/jfmv/Documents/Proyectos/Delafossites/integration_delafossite/MD_int/Res_opt/ActualJ/Half_F/dsf3_1000_Q/T_"+str(T)+'_fit.npy', 'rb') as f:

        xFS_dense = np.load(f)
        yFS_dense = np.load(f)
        angles = np.load(f)
        shifts = np.load(f)
    scatter(angles, shifts, s=3)


    ##scales with temperature

# %%
for T in [1.0,2.0,3.0,10.0,50.0]:
    with open("/Users/jfmv/Documents/Proyectos/Delafossites/integration_delafossite/MD_int/Res_opt/ActualJ/Half_F/dsf3_1000_noQ/T_"+str(T)+'_fit.npy', 'rb') as f:

        xFS_dense = np.load(f)
        yFS_dense = np.load(f)
        angles = np.load(f)
        shifts = np.load(f)
    scatter(angles, shifts/(T), s=3)

# %%
for T in [1.0,2.0,3.0,10.0,50.0]:
    with open("/Users/jfmv/Documents/Proyectos/Delafossites/integration_delafossite/MD_int/Res_opt/ActualJ/Half_F/dsf3_1000_Qnocenter/T_"+str(T)+'_fit.npy', 'rb') as f:

        xFS_dense = np.load(f)
        yFS_dense = np.load(f)
        angles = np.load(f)
        shifts = np.load(f)
    scatter(angles, shifts, s=3)
