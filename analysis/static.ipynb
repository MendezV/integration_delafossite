# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python3.9/site-packages/IPython/core/magics/pylab.py:159: UserWarning: pylab import has clobbered these variables: ['f']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %%
EET=[]
file1='angles_FS_J=10.34_T=1.0_nofit_SF_func_diffpeak_only_1_4.0_parabolic_disp.npy'
file2='SelfE_J=10.34_T=1.0_nofit_SF_func_diffpeak_only_1_4.0_parabolic_disp.npy'
path="/Users/jfmv/Documents/Proyectos/Delafossites/integration_delafossite/Modular/reproducing_bug_diff_peak_circular_FS_0.1_filling_1000_samplesdir_T_1.0_nofit_SF_func_diffpeak_only_1_4.0_2021-11-11-14:18:40/"
path_c=path+file1
with open(path_c, 'rb') as f:
    ang=np.load(f)
path_c=path+file2
with open(path_c, 'rb') as f:
    integ=np.load(f)

scatter(ang, integ)

# %%
EET=[]
file1='angles_FS_J=10.34_T=1.0_nofit_SF_func_diffpeak_only_1_4.0_parabolic_disp.npy'
file2='SelfE_J=10.34_T=1.0_nofit_SF_func_diffpeak_only_1_4.0_parabolic_disp.npy'
path="/Users/jfmv/Documents/Proyectos/Delafossites/integration_delafossite/Modular/fixing_bug_diff_peak_circular_FS_0.1_filling_1000_samplesdir_T_1.0_nofit_SF_func_diffpeak_only_1_4.0_2021-11-11-14:24:24/"
path_c=path+file1
with open(path_c, 'rb') as f:
    ang2=np.load(f)
path_c=path+file2
with open(path_c, 'rb') as f:
    integ2=np.load(f)

scatter(ang2, integ2)

# %%
EET=[]
file1='angles_FS_J=10.34_T=1.0_nofit_SF_func_diffpeak_only_1_4.0_parabolic_disp.npy'
file2='SelfE_J=10.34_T=1.0_nofit_SF_func_diffpeak_only_1_4.0_parabolic_disp.npy'
path="/Users/jfmv/Documents/Proyectos/Delafossites/integration_delafossite/Modular/fixing_bug_smallerBZ_diff_peak_circular_FS_0.1_filling_1000_samplesdir_T_1.0_nofit_SF_func_diffpeak_only_1_4.0_2021-11-11-14:28:55/"
path_c=path+file1
with open(path_c, 'rb') as f:
    ang3=np.load(f)
path_c=path+file2
with open(path_c, 'rb') as f:
    integ3=np.load(f)

scatter(ang3, integ3)

# %%
scatter(ang[::3], integ[::3])
scatter(ang2[::3], integ2[::3])
scatter(ang3[::3], integ3[::3])

# %%
scatter(ang, integ)
scatter(ang2, integ2)
scatter(ang3, integ3)

# %%
EET=[]
file1='angles_FS_J=10.34_T=1.0_nofit_SF_func_diffpeak_only_1_4.0_parabolic_disp.npy'
file2='SelfE_J=10.34_T=1.0_nofit_SF_func_diffpeak_only_1_4.0_parabolic_disp.npy'
path="/Users/jfmv/Documents/Proyectos/Delafossites/integration_delafossite/Modular/reproducing_bug_diff_peak_circular_FS_0.1_filling_1500_samplesdir_T_1.0_nofit_SF_func_diffpeak_only_1_4.0_2021-11-11-14:58:22/"
path_c=path+file1
with open(path_c, 'rb') as f:
    ang=np.load(f)
path_c=path+file2
with open(path_c, 'rb') as f:
    integ=np.load(f)

scatter(ang, integ)

# %%
EET=[]
file1='angles_FS_J=10.34_T=1.0_nofit_SF_func_diffpeak_only_1_4.0_parabolic_disp.npy'
file2='SelfE_J=10.34_T=1.0_nofit_SF_func_diffpeak_only_1_4.0_parabolic_disp.npy'
path="/Users/jfmv/Documents/Proyectos/Delafossites/integration_delafossite/Modular/fixing_bug_diff_peak_circular_FS_0.1_filling_1500_samplesdir_T_1.0_nofit_SF_func_diffpeak_only_1_4.0_2021-11-11-15:21:37/"
path_c=path+file1
with open(path_c, 'rb') as f:
    ang2=np.load(f)
path_c=path+file2
with open(path_c, 'rb') as f:
    integ2=np.load(f)

scatter(ang2, integ2)

# %%
EET=[]
file1='angles_FS_J=10.34_T=1.0_nofit_SF_func_diffpeak_only_1_4.0_parabolic_disp.npy'
file2='SelfE_J=10.34_T=1.0_nofit_SF_func_diffpeak_only_1_4.0_parabolic_disp.npy'
path="/Users/jfmv/Documents/Proyectos/Delafossites/integration_delafossite/Modular/fixing_bug_smallerBZ_diff_peak_circular_FS_0.1_filling_1500_samplesdir_T_1.0_nofit_SF_func_diffpeak_only_1_4.0_2021-11-11-15:08:40/"
path_c=path+file1
with open(path_c, 'rb') as f:
    ang3=np.load(f)
path_c=path+file2
with open(path_c, 'rb') as f:
    integ3=np.load(f)

scatter(ang3, integ3)
# axvline(2*np.pi/6)

# %%
# scatter(ang, integ, s=1)
scatter(ang2, integ2, s=1)
axvline(2*np.pi/4, c='r')
axvline(0*2*np.pi/4, c='r')
axvline(-2*np.pi/4, c='r')
# scatter(ang3, integ3)

# %%
scatter(ang, integ, s=1)
# scatter(ang2, integ2, s=1)
axvline(3*2*np.pi/6, c='r')
axvline(2*2*np.pi/6, c='r')
axvline(2*np.pi/6, c='r')
axvline(0*2*np.pi/6, c='r')
axvline(-2*np.pi/6, c='r')
axvline(-2*2*np.pi/6, c='r')
axvline(-3*2*np.pi/6, c='r')
# scatter(ang3, integ3)

# %%
EET=[]
file1='angles_FS_J=10.34_T=10.0_nofit_SF_func_diffpeak_only_1_4.0_parabolic_disp.npy'
file2='SelfE_J=10.34_T=10.0_nofit_SF_func_diffpeak_only_1_4.0_parabolic_disp.npy'
path="/Users/jfmv/Documents/Proyectos/Delafossites/integration_delafossite/Modular/cutoff_freq_w_0_sq_grid_sq_domain_circular_FS_0.1_filling_1000_sample_5000_FSpoints_precise_contourdir_T_10.0_nofit_SF_func_diffpeak_only_1_4.0_2021-11-12-15:59:35/"
path_c=path+file1
with open(path_c, 'rb') as f:
    ang=np.load(f)
path_c=path+file2
with open(path_c, 'rb') as f:
    integ=np.load(f)

scatter(ang, integ, s=1)
ang[np.argmax(integ)]
# Out:
# 1.5733805905417957

# %%
np.argmax(integ)
# Out:
# 3068

# %%
ang[3068]
# Out:
# 1.5733805905417957
