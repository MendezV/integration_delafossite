# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/jfm343/anaconda3/lib/python3.8/site-packages/IPython/core/magics/pylab.py:159: UserWarning: pylab import has clobbered these variables: ['f']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %%
EET=[]
path="/Users/jfmv/Documents/Proyectos/Delafossites/data/T_wdep_fit_point_FS_dense_2021-11-07-14-09-27/T_wdep_fit_point_FS_dense_"
for i in range(1,11):
    a=0
    path_c=path +str(i)+"/SelfE_J=10.34_T="+str(i)+".0_fit_SF_func_lattice_disp.npy"
    with open(path_c, 'rb') as f:
            integ=np.load(f)
            omega=np.linspace(0,2*i,np.size(integ))*10.34
            sigma=integ/integ[0]
            ya=sigma
            xa=omega
            EET.append(integ[0])

            plot(xa,ya)
            scatter(xa,ya, s=2)
            xlim(-0.51,10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-eccbf74b7dc8> in <module>
#       4     a=0
#       5     path_c=path +str(i)+"/SelfE_J=10.34_T="+str(i)+".0_fit_SF_func_lattice_disp.npy"
# ----> 6     with open(path_c, 'rb') as f:
#       7             integ=np.load(f)
#       8             omega=np.linspace(0,2*i,np.size(integ))*10.34
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/jfmv/Documents/Proyectos/Delafossites/data/T_wdep_fit_point_FS_dense_2021-11-07-14-09-27/T_wdep_fit_point_FS_dense_1/SelfE_J=10.34_T=1.0_fit_SF_func_lattice_disp.npy'

# %%
Ts=arange(1,11,1)
plot(Ts,EET/EET[0])
scatter(Ts,EET/EET[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-55ca0c050be9> in <module>
#       1 Ts=arange(1,11,1)
# ----> 2 plot(Ts,EET/EET[0])
#       3 scatter(Ts,EET/EET[0])
#
# IndexError: list index out of range

# %%
EET=[]
path="/Users/jfmv/Documents/Proyectos/Delafossites/data/T_wdep_fit_point_FS_dense_2000_2Trange_theta075_2021-11-09-22-10-25/T_wdep_fit_point_FS_dense_2000_2Trange_theta075_"
for i in range(1,11):
    a=0
    path_c=path +str(i)+"/SelfE_J=10.34_T="+str(i)+".0_fit_SF_func_lattice_disp.npy"
    with open(path_c, 'rb') as f:
            integ=np.load(f)
            omega=np.linspace(0,2*i,np.size(integ))*10.34
            sigma=integ/integ[0]
            ya=sigma
            xa=omega
            EET.append(integ[0])

            plot(xa,ya)
            scatter(xa,ya, s=2)
            xlim(-0.51,10)

# %%
Ts=arange(1,11,1)
plot(Ts,EET/EET[0])
scatter(Ts,EET/EET[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-55ca0c050be9> in <module>
#       1 Ts=arange(1,11,1)
# ----> 2 plot(Ts,EET/EET[0])
#       3 scatter(Ts,EET/EET[0])
#
# IndexError: list index out of range

# %%
EET=[]
path="/Users/jfmv/Documents/Proyectos/Delafossites/data/T_wdep_fit_point_FS_dense_2000_2Trange_theta05_2021-11-09-22-56-17/T_wdep_fit_point_FS_dense_2000_2Trange_theta05_"
for i in range(1,11):
    a=0
    path_c=path +str(i)+"/SelfE_J=10.34_T="+str(i)+".0_fit_SF_func_lattice_disp.npy"
    with open(path_c, 'rb') as f:
            integ=np.load(f)
            omega=np.linspace(0,2*i,np.size(integ))*10.34
            sigma=integ/integ[0]
            ya=sigma
            xa=omega
            EET.append(integ[0])

            plot(xa,ya)
            scatter(xa,ya, s=2)
            xlim(-0.51,10)

# %%
Ts=arange(1,11,1)
plot(Ts,EET/EET[0])
scatter(Ts,EET/EET[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-55ca0c050be9> in <module>
#       1 Ts=arange(1,11,1)
# ----> 2 plot(Ts,EET/EET[0])
#       3 scatter(Ts,EET/EET[0])
#
# IndexError: list index out of range

# %%
EET=[]
path="/home/jfm343/Documents/Delafossites/integration_delafossite/data/wT_sweep_theta_MC_6000_2021-12-07-05-11-08/wT_sweep_theta_MC_6000_"
thetas=['18.0','24.0','30.0']#, '6.0', '0.0']
for i in range(1,11):
    for thet in thetas:
        a=0
        path_c=path +str(i)+"/DataRun/SelfE_J=10.34_T="+str(i)+".0_fit_SF_func_theta_"+thet+"_lattice_disp.npy"
        path_w=path +str(i)+"/DataRun/w_FS_J=10.34_T="+str(i)+".0_fit_SF_func_theta_"+thet+"_lattice_disp.npy"
        with open(path_c, 'rb') as f:
            integ=np.load(f)
            sigma=integ#-integ[0]
            ya=sigma
            EET.append(integ[0])
        with open(path_w, 'rb') as f:

                omega=np.load(f)
                xa=omega
        plot(xa,ya)
        scatter(xa,ya, s=2)
        
        ylabel(r"Im$\Sigma(k,\omega, T)$ (mev)")
        xlabel(r"$\omega$ (mev)")
        #xlim(-0.51,20)

# %%
EET=[]
path="/home/jfm343/Documents/Delafossites/integration_delafossite/data/wT_sweep_theta_MC_6000_2021-12-07-05-11-08/wT_sweep_theta_MC_6000_"
thetas=['18.0','24.0','30.0']#, '6.0', '0.0']

J=10.34
for i in range(1,11):
    for thet in thetas:
        a=0
        path_c=path +str(i)+"/DataRun/SelfE_J=10.34_T="+str(i)+".0_fit_SF_func_theta_"+thet+"_lattice_disp.npy"
        path_w=path +str(i)+"/DataRun/w_FS_J=10.34_T="+str(i)+".0_fit_SF_func_theta_"+thet+"_lattice_disp.npy"
        with open(path_c, 'rb') as f:
            integ=np.load(f)
            sigma=integ-integ[0]
            ya=sigma
            EET.append(integ[0])
        with open(path_w, 'rb') as f:

                omega=np.load(f)
                xa=omega
        plot(xa,ya)
        scatter(xa,ya, s=2)
        xlim(-0.51,20)
        ylabel(r"Im($\Sigma(k,\omega, T)-\Sigma(k,0, T)$) (mev)")
        xlabel(r"$\omega$ (mev)")

# %%
EET=[]
path="/home/jfm343/Documents/Delafossites/integration_delafossite/data/wT_sweep_theta_MC_6000_2021-12-07-05-11-08/wT_sweep_theta_MC_6000_"
thetas=['18.0','24.0','30.0']#, '6.0', '0.0']

J=10.34
for i in range(4,11):
    for thet in thetas:
        a=0
        path_c=path +str(i)+"/DataRun/SelfE_J=10.34_T="+str(i)+".0_fit_SF_func_theta_"+thet+"_lattice_disp.npy"
        path_w=path +str(i)+"/DataRun/w_FS_J=10.34_T="+str(i)+".0_fit_SF_func_theta_"+thet+"_lattice_disp.npy"
        with open(path_c, 'rb') as f:
            integ=np.load(f)
            sigma=integ-integ[0]
            ya=sigma
            EET.append(integ[0])
        with open(path_w, 'rb') as f:

                omega=np.load(f)
                xa=omega
        # plot(xa,ya ,c=float(thet))
        scatter(xa,ya, s=2, color=cm.hot(i/15))
        ylabel(r"Im($\Sigma(k,\omega, T)-\Sigma(k,0, T)$) (mev)")
        xlabel(r"$\omega$ (mev)")
        # xlim(-0.51,1400*0.5)
        # ylim(-0.04,0.2)

# %%
EET=[]
path="/home/jfm343/Documents/Delafossites/integration_delafossite/data/wT_sweep_theta_MC_6000_2021-12-07-05-11-08/wT_sweep_theta_MC_6000_"
thetas=['18.0','24.0','30.0']#, '6.0', '0.0']

J=10.34
for i in range(1,11):
    for thet in thetas:
        a=0
        path_c=path +str(i)+"/DataRun/SelfE_J=10.34_T="+str(i)+".0_fit_SF_func_theta_"+thet+"_lattice_disp.npy"
        path_w=path +str(i)+"/DataRun/w_FS_J=10.34_T="+str(i)+".0_fit_SF_func_theta_"+thet+"_lattice_disp.npy"
        with open(path_c, 'rb') as f:
            integ=np.load(f)
            sigma=integ-integ[0]
            ya=sigma
            EET.append(integ[0])
        with open(path_w, 'rb') as f:

                omega=np.load(f)
                xa=omega/(i*J)
        plot(xa,ya)
        scatter(xa,ya, s=2)
        ylabel(r"Im($\Sigma(k,\omega, T)-\Sigma(k,0, T)$) (mev)")
        xlabel(r"$\omega/T$ ")
        #xlim(-0.51,20)

# %%
EET=[]
TT=[]
th=[]
mins=[]
argmins=[]
wargmins=[]
path="/home/jfm343/Documents/Delafossites/integration_delafossite/data/wT_sweep_theta_MC_6000_2021-12-07-05-11-08/wT_sweep_theta_MC_6000_"
thetas=['18.0','24.0','30.0']#, '6.0', '0.0']

J=10.34
for i in range(1,11):
    for thet in thetas:
        a=0
        path_c=path +str(i)+"/DataRun/SelfE_J=10.34_T="+str(i)+".0_fit_SF_func_theta_"+thet+"_lattice_disp.npy"
        path_w=path +str(i)+"/DataRun/w_FS_J=10.34_T="+str(i)+".0_fit_SF_func_theta_"+thet+"_lattice_disp.npy"
        with open(path_c, 'rb') as f:
            integ=np.load(f)
            sigma=integ-integ[0]
            ya=sigma
            TT.append(i)
            EET.append(integ[0])
            th.append(float(thet))
            mins.append(min(sigma))
            argmins.append(argmin(sigma))
        with open(path_w, 'rb') as f:

                omega=np.load(f)
                wargmins.append(omega[argmin(sigma)])
                xa=omega
        plot(xa,ya)
        scatter(xa,ya, s=2)
        #xlim(-0.51,20)

# %%
scatter(TT,EET,c=th)

# %%
scatter(TT,mins, c=th)

# %%
scatter(TT,wargmins, c=th)

# %%
EET=[]
TT=[]
th=[]
mins=[]
argmins=[]
wargmins=[]
path="/home/jfm343/Documents/Delafossites/integration_delafossite/data/q_sweep_theta_MC_6000_larger_cutoff_2021-12-08-07-21-25/q_sweep_theta_MC_6000_larger_cutoff_"
thetas=['18.0','24.0','30.0']#, '6.0', '0.0']

J=10.34
for i in range(4,11):
    for thet in thetas:
        a=0
        path_c=path +str(i)+"/DataRun/SelfE_J=10.34_T="+str(i)+".0_fit_SF_func_theta_"+thet+"_lattice_disp_w_0.0.npy"
        path_w=path +str(i)+"/DataRun/qq_FS_J=10.34_T="+str(i)+".0_fit_SF_func_theta_"+thet+"_lattice_disp_w_0.0.npy"
        with open(path_c, 'rb') as f:
            integ=np.load(f)
            sigma=integ-integ[0]
            ya=sigma
            TT.append(i)
            EET.append(integ[0])
            th.append(float(thet))
            mins.append(min(sigma))
            argmins.append(argmin(sigma))
        with open(path_w, 'rb') as f:

                qq=np.load(f)
                q=np.sqrt(qq[:,0]**2+qq[:,1]**2)
                wargmins.append(q[argmin(sigma)])
                xa=q
        # plot(xa,ya)
        scatter(xa,ya,s=16,  color=cm.hot(i/15), label=str(np.round(float(thet)*np.pi/180,3))+"  "+str(i))
        ylabel(r"Im($\Sigma(q_{\perp}+k_f,0,s T)-\Sigma(k_f,0, T)$) (mev)")
        xlabel(r"$q_{\perp}$ ")
    legend()
