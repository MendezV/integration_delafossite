# %%
# %pylab inline
import numpy as np
import pandas as pd
import os
import sys
sys.path.insert(0, '/home/jfm343/Documents/Delafossites/integration_delafossite/Modular')
import Dispersion
import Lattice
from scipy import linalg as la
import seaborn as sns
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# pathMAC="/Users/jfmv/Documents/Proyectos/Moire-Phonon_QMC/BM_bandstructure"
pathchow='/home/jfm343/Documents/Delafossites/integration_delafossite/Modular/'
pathMAC='/Users/juanmendezvalderrama/Documents/Proyectos/Delafossites/integration_delafossite/Modular/'
pathUBU='/home/juan/Documents/Projects/Delafossites/integration_delafossite/Modular/'
pathy=pathchow

# %%
path=pathy+'data2022-05-24-10-48-59.h5'
df = pd.read_hdf(path)
tss=df['T'].unique()


l=Lattice.TriangLattice(10,10,'CH1')
[vx,vy]=l.boundary()
plt.plot(vx,vy, c='k')
plt.scatter(df['KFX'], df['KFY'],c=df['SE'],  s=15)
plt.gca().set_aspect('equal', adjustable='box')
plt.colorbar()
plt.show()



# path=pathy+'data2022-04-30-10-52-10.h5'
# df = pd.read_hdf(path)
df=df.sort_values(by=['theta'])
SEromb_inter02=df['SE']
th2=df['theta']
plt.scatter(df['theta'], df['SE'],  s=15)
plt.plot(df['theta'], df['SE'])
plt.ylim([1.98,2.07])
plt.show()


plt.plot(vx,vy, c='k')
cutoff=2.025
plt.scatter(df['KFX'][df['SE']<cutoff], df['KFY'][df['SE']<cutoff],c=df['SE'][df['SE']<cutoff],  s=15)
plt.gca().set_aspect('equal', adjustable='box')
plt.colorbar()
plt.show()

plt.scatter(df['theta'][df['SE']<cutoff], df['SE'][df['SE']<cutoff],  s=15)
plt.plot(df['theta'][df['SE']<cutoff], df['SE'][df['SE']<cutoff])
plt.ylim([1.98,2.07])
plt.show()
# Out:
# Machine arg is, CH1

# %%
path=pathy+'data2022-05-24-11-15-25.h5'
df = pd.read_hdf(path)
tss=df['T'].unique()


l=Lattice.TriangLattice(10,10,'CH1')
[vx,vy]=l.boundary()
plt.plot(vx,vy, c='k')
plt.scatter(df['KFX'], df['KFY'],c=df['SE'],  s=15)
plt.gca().set_aspect('equal', adjustable='box')
plt.colorbar()
plt.show()




df=df.sort_values(by=['theta'])
SEromb_inter02=df['SE']
th2=df['theta']
plt.scatter(df['theta'], df['SE'],  s=15)
plt.plot(df['theta'], df['SE'])
# plt.ylim([1.98,2.07])
plt.show()
# Out:
# Machine arg is, CH1

# %%
path=pathy+'Firs005data2022-05-24-13-13-36.h5'
df = pd.read_hdf(path)
tss=df['T'].unique()


l=Lattice.TriangLattice(10,10,'CH1')
[vx,vy]=l.boundary()
plt.plot(vx,vy, c='k')
plt.scatter(df['KFX'], df['KFY'],c=df['SE'],  s=15)
plt.gca().set_aspect('equal', adjustable='box')
plt.colorbar()
plt.show()




df=df.sort_values(by=['theta'])
SEromb_inter02=df['SE']
th2=df['theta']
plt.scatter(df['theta'], df['SE'],  s=15)
plt.plot(df['theta'], df['SE'])
# plt.ylim([1.98,2.07])
plt.show()
# Out:
# Machine arg is, CH1

# %%
path=pathy+'data2022-05-24-14-05-45.h5'
df = pd.read_hdf(path)
tss=df['T'].unique()


l=Lattice.TriangLattice(10,10,'CH1')
[vx,vy]=l.boundary()
plt.plot(vx,vy, c='k')
plt.scatter(df['KFX'], df['KFY'],c=df['SE'],  s=15)
plt.gca().set_aspect('equal', adjustable='box')
plt.colorbar()
plt.show()




df=df.sort_values(by=['theta'])
SEromb_inter02=df['SE']
th2=df['theta']
plt.scatter(df['theta'], df['SE'],  s=15)
plt.plot(df['theta'], df['SE'])
# plt.ylim([3,4.07])
plt.show()
# Out:
# Machine arg is, CH1
